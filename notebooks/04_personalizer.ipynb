# %% [markdown]
# # 04 - Personalizer Agent
# ## Matches articles to each user's interests
# ## Picks top 10 most relevant articles per user

# %%
import asyncpg
import json
from groq import AsyncGroq
from dotenv import load_dotenv
import os

load_dotenv()

DATABASE_URL = "postgresql://postgres:postgres@localhost:5432/ainews"
GROQ_API_KEY = os.getenv("9Z4K6GdVYfukYbvO2VNYWGdyb3FYjVpc4eCOoVIH9lVMf5GyJ859")
client_groq  = AsyncGroq(api_key=GROQ_API_KEY)

print("✅ Imports done")
# Out:
# ✅ Imports done
